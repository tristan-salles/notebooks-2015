# %% [markdown]
# # GEOS3102: Global Energy & Resources
# <br/>
# ### Quantitative approach to basin exploration
# <br/>
# #### Week 6

# %% [markdown]
# # Outline
# <br/>
# ### Analogue modelling

# %% [markdown]
# ### Stratigraphic forward modelling

# %% [markdown]
# # Why using models?
#
# At the basin, field and reservoir scale we often have:
#
# + limited local observations (wells - few cores)
# + 2D, 3D/4D seismic information
# + EM and/or potential-field data (gravity & magnetics)
# + analogue field data often remote from the area of interest
# + global (paleo-) studies of climate, sedimentology, water-level
#
# ---

# %% [markdown]
# # Why using models?
#
# And we want to use this information to predict:
#
# + where (remaining) commercial volumes of Oil&Gas exist in the subsurface away from existing wells
# + the probability of hydrocarbons remaining between wells after production
# + the likelihood of subtle traps containing commercial volumes below seismic resolution
#
# ---

# %% [markdown]
# # Analogue modelling
# <br/>
# <div align="center">
#     <img width=1500 src="http://d32ogoqmya1dw8.cloudfront.net/images/NAGTWorkshops/sedimentary/models/low_resolution_xes_basin.jpg" title="Synthethic stratigraphy created in an XES Basin experimental run (XES 02)"</img>
#     <small>source: [SAFL](http://serc.carleton.edu/NAGTWorkshops/sedimentary/models/xes_basin_project.html)</small>
# </div>
#
# ---
#
# - Field study is the ultimate repository of information, but **exposure is limited**, and it is often **difficult to constrain key governing variables** independently.

# %% [markdown]
# # Analogue modelling
# <br/>
# <div align="center">
#     <img width=1500 src="http://d32ogoqmya1dw8.cloudfront.net/images/NAGTWorkshops/sedimentary/models/low_resolution_xes_basin.jpg" title="Synthethic stratigraphy created in an XES Basin experimental run (XES 02)"</img>
#     <small>source: [SAFL](http://serc.carleton.edu/NAGTWorkshops/sedimentary/models/xes_basin_project.html)</small>
# </div>
#
# ---
#
# - Analogue modelling produces experimental stratigraphy under precisely **controlled and monitored conditions** of sediment supply, subsidence, base-level variation, and transport mechanics.

# %% [markdown]
# ## Experimental stratigraphy

# %%
from IPython.core.display import HTML
HTML('<center><iframe src=http://www.geosociety.org/gsatoday/archive/11/7/pdf/i1052-5173-11-7-4.pdf width=800 height=800></iframe></center>')
# Out:
# <center><iframe src=http://www.geosociety.org/gsatoday/archive/11/7/pdf/i1052-5173-11-7-4.pdf width=800 height=800></iframe></center>

# %% [markdown]
# ## Why was the XES (Experimental Earthscape Facility) Basin built?
# <br/>
# <div align="center">
#     <img width=700 src="http://d32ogoqmya1dw8.cloudfront.net/images/NAGTWorkshops/sedimentary/models/xes_basin_thumb.jpg" title="Experimental Earthscape Facility (XES basin) experiment in progress"</img>
#     <small>source: [SEPM](http://www.sepmstrata.org/page.aspx?pageid=410)</small>
# </div>
#
# ---
#
# Four fundamental rates govern the architecture of sedimentary basin filling:
#
# 1. **sediment supply;**
# 2. **water supply; **
# 3. **base level change;** and
# 4. **tectonic subsidence.**

# %% [markdown]
# ## Why was the XES (Experimental Earthscape Facility) Basin built?
# <br/>
# <div align="center">
#     <img width=700 src="http://d32ogoqmya1dw8.cloudfront.net/images/NAGTWorkshops/sedimentary/models/xes_basin_thumb.jpg" title="Experimental Earthscape Facility (XES basin) experiment in progress"</img>
#     <small>source: [SEPM](http://www.sepmstrata.org/page.aspx?pageid=410)</small>
# </div>
#
# ---
#
# - An experimental facility that effectively simulates all of these fundamental controls should provide considerable insight into **how sedimentary basins evolve over geologic timescales and respond to external forcings**.
# - Sediment, water and base level rates are relatively easy to control in an experiment, but it is very difficult to model **tectonic subsidence**, particularly if one is interested in studying a range of subsidence geometries.
# - The XES basin uses a **unique subsidence mechanism** to address this last issue.

# %% [markdown]
# ## Why was the XES (Experimental Earthscape Facility) Basin built?
#
# The XES Basin was built to address fundamental questions about the controls on sedimentary basin architecture and geomorphology, including:
#
# - **Are there unique stratal signatures created by changes in base level versus changes in tectonic subsidence?**

# %% [markdown]
# - **What are the stratal signatures of climate change? Can a climate signal be differentiated from a tectonic signal based on stratal geometries alone? **

# %% [markdown]
# - **Are numerical models of sedimentary basin filling robust and calibrated? Can these numerical models predict the outcome of an experiment where all of the initial and boundary conditions are known?**

# %% [markdown]
# - **Do continuous turbidity currents create a different basin fill than episodic/instantaneous flows?**

# %% [markdown]
# - **What controls the stacking geometry and connectivity of alluvial channels in the stratigraphic record?**

# %% [markdown]
# - **How do geomorphic rates control stratal geometries?**

# %% [markdown]
# Furthermore, by creating detailed two- and three-dimensional images of the basin deposit and architecture, it is possible to **simulate subsurface fluid flow** and to develop **synthetic seismic images** that can assist in **hydrogeological and petroleum resource applications**.

# %% [markdown]
# ## How doest it work?
#
# <div align="center">
#     <img width=400 src="http://d32ogoqmya1dw8.cloudfront.net/images/NAGTWorkshops/sedimentary/models/diagram_depicting_mechanics_xe_1214487313.jpg" title="SAFL Jurassic Tank"</img>
#     <small>source: [SAFL](http://serc.carleton.edu/NAGTWorkshops/sedimentary/models/how_xes_basin_works.html)</small>
# </div>
#
# ---
#
# - The XES facility is a large basin: **13 m x 6.5 m**.

# %% [markdown]
# - The basin floor is a honeycomb of 432 independent subsidence cells (see image) through which a gravel basement is slowly extracted from below, providing space to accommodate deposition.

# %% [markdown]
# - The top of the gravel is covered with a thin rubber membrane, which forms the base of the experimental deposit.

# %% [markdown]
# - Premixed sediment and water can be fed from anywhere along the perimeter of the basin, and base level is independently set by a computer-controlled head tank mounted outside of the basin.

# %% [markdown]
# - Surface flow pattern is recorded using video and still cameras. Topographic scanning system is also used for stratigraphic evolution analysis.

# %% [markdown]
# ## Experiment XES10
#
# - In the experiment, water mixed with a 50%:50% blend (by volume) of fine (120 mm) *quartz* and *coal* sand was fed from a single source point into one side of the basin
# - base level was adjusted from the other side.
# - more buoyant coal sands (specific gravity of 1.3 $kg.m^{-2}.s^{-2}$) were a visibly distinct proxy for sediments that were finer-grained and slower-settling than the quartz sands (specific gravity 2.65 $kg.m^{-2}.s^{-2}$).

# %% [markdown]
# - subsidence rates were varied across the basin so as to produce a simple bowl-shaped geometry centered over the middle of the basin.
# - the rates of subsidence and of water and sediment discharge were **held constant throughout the experiment**.
# - the **only factor that was varied was base level**. This history included a slow fall and rise of base level followed hours later by a rapid fall and rise.

# %%
from IPython.display import YouTubeVideo
# XES 10 Timelapse Overhead Images https://youtu.be/WWi39PWrHeY
YouTubeVideo('WWi39PWrHeY')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/WWi39PWrHeY"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <br/>
# <div align="center">
#     <img width=700 src="https://nicholas.duke.edu/people/faculty/pratson/seismic/JTCube.jpg" title="SAFL Jurassic Tank Exp1"</img>
#     <small>[source](https://nicholas.duke.edu/people/faculty/pratson/seismic/temp.htm)</small>
# </div>
#
# ---
#
# - Basin strata sliced lengthwise at intervals of 2.5 cm. Each cross-sectional slice was digitally photographed, allowing the strata to be digitally reassembled and viewed in three dimensions.

# %% [markdown]
# ## Experiment XES10
# <br/>
#
# <div align="center">
#     <img width=1000 src="https://nicholas.duke.edu/people/faculty/pratson/seismic/JTCrossSectionbig.jpg" title="SAFL Jurassic Tank Exp1"</img>
#     <small>[source](https://nicholas.duke.edu/people/faculty/pratson/seismic/temp.htm)</small>
# </div>
#
# ---
#
# - The photographic panel shown above is an example of such a cross section. This particular panel is located just off the center dipline through the basin. Labels on the photograph identify a range of deposits and structures in the strata and indicate the relative timing of their formation with respect to the changes in base level that occurred during the experiment (graph below panel).

# %% [markdown]
# ## Experiment XES10
# <br/>
#
# <div align="center">
#     <img width=1000 src="https://gprgindonesia.files.wordpress.com/2012/03/51.jpg" title="SAFL Jurassic Tank Exp1"</img>
#     <small>[source](https://gprgindonesia.wordpress.com/page/10/)</small>
# </div>
#
# ---
#
# - The experimental strata clearly capture in miniature the sequence stratagraphic architecture of basin strata, i.e., **the structures, stratal patterns and facies distributions**. Therefore, because of the natural, scale-independent appearance of the experimental strata, we simply assume that its architecture can be resized to basin proportions and used to generate synthetic seismic data at exploration frequencies.

# %% [markdown]
# ## Experiment XES10
# <br/>
#
# <div align="center">
#     <img width=1000 src="https://nicholas.duke.edu/people/faculty/pratson/seismic/ModelingScheme.jpg" title="SAFL Jurassic Tank Exp1 modelling"</img>
#     <small>[source](https://nicholas.duke.edu/people/faculty/pratson/seismic/temp.htm)</small>
# </div>
#
# ---
#
# In the digital photos of the experimental strata, the **lightest areas** in the deposit are **quartz sand**, and the **darkest areas** are **coal**, which, as mentioned above, is used as a proxy for **mud**.
# The grey scales in the photos are converted into **acoustic models**, which in turn are then used to simulate **seismic data**.

# %% [markdown]
# ## Experiment XES10
# <br/>
#
# <div align="center">
#     <img width=1000 src="https://nicholas.duke.edu/people/faculty/pratson/seismic/ModelingScheme.jpg" title="SAFL Jurassic Tank Exp1 modelling"</img>
#     <small>[source](https://nicholas.duke.edu/people/faculty/pratson/seismic/temp.htm)</small>
# </div>
#
# ---
#
# One of the simplest procedures for doing this is as follows:
#
# - Assign dimensions to each pixel in the digital photo (in the case shown, dx = 1m, dy = 5m).
# - Convert the gray scale value of each pixel (0 - 225) to a value of bulk density (A)
# - Compute porosities from the bulk densities.
# - Compute P-wave velocities (B) from the porosities using an empirical relation (e.g. Hamilton, 1980): $V_p=a_0+a_1\phi+a_2\phi^2$ where $\phi$ is the porosity.
# - Compute models of acoustic impedance and reflectivity (C) from the densities and velocities.
# - Convolve the reflectivity model with a seismic source wavelet (D) to produce normal-incidence seismic data.

# %% [markdown]
# ## Experiment XES10
#
# ### Convolution model
#
# <div align="center">
#     <img width=500 src="https://nicholas.duke.edu/people/faculty/pratson/seismic/ConvolutionModeltop.jpg" title="SAFL Jurassic Tank Exp1 modelling convolution"</img>
#     <small>[source](https://nicholas.duke.edu/people/faculty/pratson/seismic/temp.htm)</small>
# </div>
#
#  ---
#
#  Simple [convolutional modeling](http://subsurfwiki.org/wiki/Convolutional_model) of seismic data simulates ideally processed seismic data.
# It does not simulate:
#
# - seismic wave propagation, nor
# - its effects on the recorded seismograms.
#
# Therefore, the convolutional simulation is theoretically the _best_ data that can be obtained with a given seismic source.

# %% [markdown]
# ## Experiment XES10
#
# ### Convolution model
#
# <br/>
#
# <div align="center">
#     <img width=800 src="https://nicholas.duke.edu/people/faculty/pratson/seismic/ConvModlkey.jpg" title="SAFL Jurassic Tank Exp1 modelling convolution2"</img>
#     <small>[source](https://nicholas.duke.edu/people/faculty/pratson/seismic/temp.htm)</small>
# </div>

# %% [markdown]
# ## Experiment XES10
#
# ### One-Way Wave Equation
#
# <div align="center">
#     <img width=500 src="https://nicholas.duke.edu/people/faculty/pratson/seismic/OneWayWaveEquationtop.jpg" title="SAFL Jurassic Tank Exp1 modelling 1 way eq"</img>
#     <small>[source](https://nicholas.duke.edu/people/faculty/pratson/seismic/temp.htm)</small>
# </div>
#
#  ---
#
# More realistic simulations of seismic data are obtained by numerically solving the **wave equation**.
# The so-called _exploding reflector_ model, which solves the wave equation for upward propagating waves. This model accounts for :
#
# - diffractions and
# - lateral wave propagation.

# %% [markdown]
# ## Experiment XES10
#
# ### One-Way Wave Equation
#
# <br/>
#
# <div align="center">
#     <img width=800 src="https://nicholas.duke.edu/people/faculty/pratson/seismic/OneWayModl.jpg" title="SAFL Jurassic Tank Exp1 modelling one way eq 2"</img>
#     <small>[source](https://nicholas.duke.edu/people/faculty/pratson/seismic/temp.htm)</small>
# </div>

# %% [markdown]
# ## Experiment XES10
#
# ### Two-Way Wave Equation
#
# <div align="center">
#     <img width=500 src="https://nicholas.duke.edu/people/faculty/pratson/seismic/TwoWayWaveEquationtop.jpg" title="SAFL Jurassic Tank Exp1 modelling 2 way eq"</img>
#     <small>[source](https://nicholas.duke.edu/people/faculty/pratson/seismic/temp.htm)</small>
# </div>
#
#  ---
#
# Solution of the two-way wave equation simulates the full propagation of seismic waves, from their source, through multi-layered strata, to their arrival at surface receivers.
# This more realistic model of wave propagation in two dimensions accounts for such additional effects as:
#
# - geometrical spreading,
# - multiples refractions and reflections at interfaces.
#
# The model can be used to simulate multichannel seismic data.

# %% [markdown]
# ## Experiment XES10
#
# ### Two-Way Wave Equation
#
# <br/>
#
# <div align="center">
#     <img width=800 src="https://nicholas.duke.edu/people/faculty/pratson/seismic/TwoWayModl.jpg" title="SAFL Jurassic Tank Exp1 modelling two way eq 2"</img>
#     <small>[source](https://nicholas.duke.edu/people/faculty/pratson/seismic/temp.htm)</small>
# </div>

# %% [markdown]
# ## Example of tested models with the XES basin
# <br/>
#
# <div align="center">
#     <img width=1000 src="http://www.nsf.gov/news/mmg/media/images/earth_system4_h.jpg" title="SAFL Jurassic Tank"</img>
#     <small>source: [NSF](http://www.nsf.gov/news/news_images.jsp?cntn_id=112776&org=NSF)</small>
# </div>
#
# ---
#
# - **Effects of changes in base level under constant subsidence conditions**. This was the prototype run of a small-scale version of the XES basin, using only ten subsidence cells. Images in this run show excellent examples of growth faults, as well as a wide range of sequence stratigraphic features.
# - **Effects of changes in subsidence rate and geometry on alluvial channel stacking patterns**.
# - **Filling of submarine mini-basins by continuous and episodic sediment gravity flows**.
# - **Effects of slow-, fast- and superimposed base level changes under constant subsidence conditions**.
# -  **Effects of normal faulting on sedimentary basin architecture**.
# -  **Effects of asymmetric subsidence geometries on multiple interacting alluvial fans**.

# %% [markdown]
# # Role of climate variation in sequence stratigraphy
# ## Lessons from analogue modelling
#
# <br/>
# <div align="center">
#     <img width=600 src="http://www.sepmstrata.org/CMS_Images/PosAllenReg.gif" title="Accommodation"</img>
#     <small>source: [SEPM](http://www.sepmstrata.org/page.aspx?pageid=410)</small>
# </div>
#
# ---
#
# - Sequence stratigraphy is largely determined by the ratio between **accommodation** and **sediment supply**.
# - General models focus predominantly on accommodation (sea level and tectonics) rather than sediment supply.
# - Most conceptual models keep sediment supply constant.
#
# **This analogue experiment explores the effect of short term variability in sediment supply on sequence stratigraphy.**

# %% [markdown]
# ## Short term supply variations
#
# ### Causes
#
# - Variations in supply from source area
#     - e.g. Jerolmack & Paola, 2010
# - Variations in vegetation type and cover
# - Variations in average water discharge and precipitation style
#     - e.g. Simpson & Castelltort, 2012
#
# <br/>
# <br/>
#
# ### Orbital forcing
#
# Milankovitch timescale forcing both influences:
#
# - Climate variation
# - Sea level variation
#
# Sediment supply changes are thus expected on similar (100 kyr) timescales.
#
# ---
#
# <br/>
# <div align="center">
#     <img width=800 src="http://www.alpineanalytics.com/Climate/DeepTime/WebDownloadImages/Plio-PleistoceneSL.7.5w.600ppi.png" title="Pliocene-Pleistocene SL detail graph"</img>
#     <small>[source](http://www.alpineanalytics.com/Climate/DeepTime.html)</small>
# </div>

# %% [markdown]
# # Experimental facility
#
# ### Eurotank flume facility at Utrecht University (the Netherlands)
#
# <br/>
# <div align="center">
#     <img width=600 src="https://pbs.twimg.com/media/B1wWN-OIgAA0xmj.jpg:large" title="EuroTank2"</img>
#     <small>[source](https://twitter.com/moving_sand)</small>
# </div>
#
# ---
#
# <br/>
# <div align="center">
#     <img width=600 src="https://pbs.twimg.com/media/B1sEvGOIEAEmon4.jpg:large" title="EuroTank"</img>
#     <small>[source](https://twitter.com/moving_sand)</small>
# </div>

# %% [markdown]
# # Experiment setup
#
# <br/>
# <div align="center">
#     <img width=400 src="figures/stratseq2.png" title="Exp setting"</img>
#     <small>[source](http://onlinelibrary.wiley.com/doi/10.1111/bre.12034/full)</small>
# </div>
#
# ---
#
# - Two flume models are run simultaneously, and four models are run in total.
# - All models have equal sea level and tectonic parameters.
# - The only difference between the 4 models is the water discharge curve.

# %% [markdown]
# # Experiment setup
#
# <br/>
# <div align="center">
#     <img width=500 src="figures/stratseq1.png" title="Exp setting input"</img>
#     <small>[source](http://onlinelibrary.wiley.com/doi/10.1111/bre.12034/full)</small>
# </div>
#
# ---
#
# - Eustatic sea level (E), discharge (Q), and subsidence (Y) scenarios.
# - All subsidence profiles show the same trend, Ymax represents the zone of maximum subsidence.
# - Models are generated at 15 time steps (t1–15). Duration between time steps varies between 3.3 and 3.9 h.
# <br/>
#
# **Constant discharge** (CD), **High-frequency discharge** (HFD), **Discharge leading base level**(D<E), **Discharge lagging base level** (D>E)

# %% [markdown]
# ## Sequence-stratigraphic interpretation
#
#
# <br/>
# <div align="center">
#     <img width=1200 src="figures/seqstrat4.png" title="seq strat"</img>
#     <small>[source](http://onlinelibrary.wiley.com/doi/10.1111/bre.12034/full)</small>
# </div>
#
# ---
#
# Sequence-stratigraphic interpretation of profiles along central axis of experiments based on the analogue models. Numbers in the figure refer to time steps. All models are aligned on the initial shoreline (0).

# %% [markdown]
# ## Erosion-deposition maps
#
#
# <br/>
# <div align="center">
#     <img width=1000 src="figures/ana3.png" title="seq strat3"</img>
#     <small>[source](http://onlinelibrary.wiley.com/doi/10.1111/bre.12034/full)</small>
# </div>
#
# ---
#
# Comparison of erosion deposition maps for 2 models. Note the overall increase in erosion during sea level fall and the pattern of erosion in small gullies.

# %% [markdown]
# ## Constant discharge & discharge leading sea level
#
#
# <br/>
# <div align="center">
#     <img width=800 src="figures/ana1.png" title="seq strat3"</img>
#     <small>[source](http://onlinelibrary.wiley.com/doi/10.1111/bre.12034/full)</small>
# </div>
#
# ---
#
# - Lower discharge leads to a **steepening of the longitudinal profile**.
# - Simultaneously, lower discharge leads to **reduced progradation**, enhancing erosion of the at the seaward end of the profile.
# - The pattern of erosion in **small gullies** is related to upstream deposition, resulting in **frequent avulsion**.

# %% [markdown]
# ## Constant discharge & discharge lagging sea level
#
#
# <br/>
# <div align="center">
#     <img width=800 src="figures/ana2.png" title="seq strat4"</img>
#     <small>[source](http://onlinelibrary.wiley.com/doi/10.1111/bre.12034/full)</small>
# </div>
#
# ---
#
# - Note that erosion is **strongest on the proximal topset and dissipates downstream.**
# - The specific pattern is related to a **lowering of the longitudinal profile** due to increased discharge, resulting in **proximal incision**
# - The high progradation rates result in **decreased erosion near the coastline**.

# %% [markdown]
# ## Shoreline-trajectory diagrams
#
#
# <br/>
# <div align="center">
#     <img width=800 src="figures/ana4.png" title="seq strat6"</img>
#     <small>[source](http://onlinelibrary.wiley.com/doi/10.1111/bre.12034/full)</small>
# </div>
#
# ---
#
# - Migration of the roll-over point does show a consistent difference between the constant discharge and high frequency discharge variation models.
# - Note that during discharge rise, the coastline progrades further or retrogrades less than during discharge fall
#
# Which suggests that:
# <br/>
# **coastline migration is affected by high frequency discharge variations even though we cannot observe the effect in a regular stratigraphic cross section.**

# %% [markdown]
# ## CSDMS laboratory movies

# %%
from IPython.core.display import HTML
HTML('<center><iframe src=http://csdms.colorado.edu/wiki/Laboratory_movies width=800 height=800></iframe></center>')
# Out:
# <center><iframe src=http://csdms.colorado.edu/wiki/Laboratory_movies width=800 height=800></iframe></center>

# %% [markdown]
# # Stratigraphic forward modelling
#
# <br/>
# <div align="center">
#     <img width=800 src="https://www2.aapg.org/europe/newsletters/2010/02feb/dionisos_fig1.jpg" title="Dionisos SFM"</img>
#     <small>[SEPM](www.sepmstrata.org)</small>
# </div>
#
# ---
#
# ### Conventional oil company geological workflow:
#
# + Describe successions at discrete locations (outcrops, wells, seismic)
# + Determine an analogue (pattern of templates) from which continuity information can be drawn.
# + Estimate what lies between wells using interpolation (drawing straight lines between similar facies boundaries in wells, or using seismic reflection property changes between well constrains)

# %% [markdown]
# # Stratigraphic forward modelling
#
# <br/>
# <div align="center">
#     <img width=800 src="https://www2.aapg.org/europe/newsletters/2010/02feb/dionisos_fig1.jpg" title="Dionisos SFM"</img>
#     <small>[SEPM](www.sepmstrata.org)</small>
# </div>
#
# ---
#
# ### SFM workflow
#
# + Describe successions at discrete locations (outcrops, wells, seismic)
# + Determine the environment(s) of deposition and the physical processes involved.
# + Determine the rates of process in the area (using biostratigraphy and isotopes)
# + Use mathematical models of the processes to predict the erosion, transport, growth, deposition, preservation of facies in the area.
# + Check that predictions match observed seismic and well data.

# %% [markdown]
# # Current status of SFM
#
# A useful overview can be obtained from the CSDMS (Community Surface Dynamics Modeling System)
#
# <br/>
#
# **There are nearly 200 models and most of them are open-source.**

# %%
from IPython.core.display import HTML
HTML('<center><iframe src=http://csdms.colorado.edu/wiki/Model_download_portal width=800 height=800></iframe></center>')
# Out:
# <center><iframe src=http://csdms.colorado.edu/wiki/Model_download_portal width=800 height=800></iframe></center>

# %% [markdown]
# ## SFM Classification
#
# The SFM family is pretty vast but for simplification it can be divided into 6 main sub-categories as follows:
#
# + Analytical models (e.g. Hardy, Lessenger, Waltham, Duan)
# + Geometric models (SedPak for example)
# + Heuristic models (including Fuzzy-logic) such as Fuzzim
# + Diffusion models (StratGem or Dionisos)
# + Hydraulic process models (Sedsim for example)
#
# Most models combine several elements of these subcategories

# %% [markdown]
# ## Example of source-to-sink experiment

# %%
from IPython.display import YouTubeVideo
# Source to Sink experiment tellus https://youtu.be/IY-9hDhDOuc
YouTubeVideo('IY-9hDhDOuc')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/IY-9hDhDOuc"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ---
#
# This animation shows the 500,000 years evolution of a landscape and stratigraphy subject to combine effect of climate and geodynamics.
# <br/>
# The model is based on a Eulerian Lagrangian approach and is called Tellus Tellus is able to simulate various type of gravity flows (rivers, turbidity and debris flows) and their associated impact on sedimentary architectures.

# %% [markdown]
# # Delta evolution based on SFM

# %%
from IPython.core.display import HTML
HTML('<center><iframe src="deltaSFM/index.html" width=1000 height=1000></iframe></center>')
#HTML('<center><iframe src="http://t-salles.github.io/assets/player/KeynoteDHTMLPlayer.html#0" width=1000 height=1000></iframe></center>')
# Out:
# <center><iframe src="deltaSFM/index.html" width=1000 height=1000></iframe></center>

# %% [markdown]
# # SFM and CO2 migration modelling
#
#
# <br/>
# <div align="center">
#     <img width=800 src="figures/gipps1.png" title="gipps1"</img>
#     <small>[source](https://www.researchgate.net/profile/John_Miranda/publication/259240166_Gippsland_Basin_stratigraphic_and_CO2_migration_modelling_workflows_for_building_regional_geological_carbon_storage_%28GCS%29_reservoir_models/links/00b4952a93537de3e6000000.pdf)</small>
# </div>
#
# ---
#
# - The Gippsland Basin, one of Australia's most prolific hydrocarbon provinces, is situated in south-eastern Australia, about 200 km east of Melbourne.
# - The basin, which has both **onshore and offshore elements**, is a world-class hydrocarbon province and contains several giant **oil and gas fields**.
# - The vast majority of the hydrocarbon discoveries are reservoired within the **siliciclastic sandstones** of the Late Cretaceous to Palaeogene Latrobe Group.
# - Almost all of the currently producing fields are located offshore within water depths of less than 200 metres.
# - Structural elements map of the Gippsland Basin showing its location in southeastern Australia.
# - The distribution of hydrocarbon resources is shown by various polygons depicting coal, oil and gas fields across the basin.

# %% [markdown]
# # SFM and CO2 migration modelling
#
#
# <br/>
# <div align="center">
#     <img width=800 src="figures/gipps2.png" title="gipps2"</img>
#     <small>[source](https://www.researchgate.net/profile/John_Miranda/publication/259240166_Gippsland_Basin_stratigraphic_and_CO2_migration_modelling_workflows_for_building_regional_geological_carbon_storage_%28GCS%29_reservoir_models/links/00b4952a93537de3e6000000.pdf)</small>
# </div>
#
# ---
#
# - Stratigraphy of the Gippsland Basin, showing petroleum system elements and a brief summary of the tectonic evolution (after Bernecker & Partridge 2001).
# - Based on lithological variations, three broad stratigraphic successions are recognised in the Gippsland Basin.
# - These stratigraphic groups comprise
#     - (1) the Strzelecki Group, a thick sequence of non-marine, volcaniclastic-rich sediments;
#     - (2) the Latrobe Group, a sequence of marine and non-marine siliciclastics that host all the known hydrocarbon occurrences in the offshore; and
#     - (3) the Seaspray Group, a carbonate-dominated sequence whose basal member is the regional seal to the oil and gas accumulations that occur within the top Latrobe Group.

# %% [markdown]
# # SFM and CO2 migration modelling
#
#
# <br/>
# <div align="center">
#     <img width=800 src="figures/gipps3.png" title="gipps3"</img>
#     <small>[source](https://www.researchgate.net/profile/John_Miranda/publication/259240166_Gippsland_Basin_stratigraphic_and_CO2_migration_modelling_workflows_for_building_regional_geological_carbon_storage_%28GCS%29_reservoir_models/links/00b4952a93537de3e6000000.pdf)</small>
# </div>
#
# ---
#
# - Sedsim Gippsland Basin stratigraphic forward model. The distribution of both porosity and grain size are shown by fences (cross-sections), while the individual data within the model are represented by small coloured points throughout the image.
# - The location of the wells used to constrain and guide the development of the model are shown for illustrative purposes as white bars.

# %% [markdown]
# # SFM and CO2 migration modelling
#
#
# <br/>
# <div align="center">
#     <img width=800 src="figures/gipps4.png" title="gipps4"</img>
#     <small>[source](https://www.researchgate.net/profile/John_Miranda/publication/259240166_Gippsland_Basin_stratigraphic_and_CO2_migration_modelling_workflows_for_building_regional_geological_carbon_storage_%28GCS%29_reservoir_models/links/00b4952a93537de3e6000000.pdf)</small>
# </div>
#
# ---
#
# - Gippsland Basin location map showing the total area modelled by Sedsim (red box) and the wells used to assist in the construction and evaluation of the model.

# %% [markdown]
# # SFM and CO2 migration modelling
#
#
# <br/>
# <div align="center">
#     <img width=500 src="figures/gipps5.png" title="gipps5"</img>
#     <small>[source](https://www.researchgate.net/profile/John_Miranda/publication/259240166_Gippsland_Basin_stratigraphic_and_CO2_migration_modelling_workflows_for_building_regional_geological_carbon_storage_%28GCS%29_reservoir_models/links/00b4952a93537de3e6000000.pdf)</small>
# </div>
#
# ---
#
# - Summary of the workflow developed to construct the regional geological carbon storage reservoir model of the Gippsland Basin.
# - Input data into the models is represented by italicised text. Red italicised text represent data incorporated and considered within Sedsim as part of the SFM process.

# %% [markdown]
# # SFM and CO2 migration modelling
#
#
# <br/>
# <div align="center">
#     <img width=800 src="figures/gipps6.png" title="gipps6"</img>
#     <small>[source](https://www.researchgate.net/profile/John_Miranda/publication/259240166_Gippsland_Basin_stratigraphic_and_CO2_migration_modelling_workflows_for_building_regional_geological_carbon_storage_%28GCS%29_reservoir_models/links/00b4952a93537de3e6000000.pdf)</small>
# </div>
#
# ---
#
# Permedia is a petroleum systems and CO2 modelling software package used to:
#
# - predict and risk high resolution petroleum migration trajectories and reservoir filling histories.
#
# As part of this workflow, Permedia was used to construct a **regional structural model of the basin** and ultimately used to **simulate CO2 injection** scenarios and related migration pathways at selected sites.
#
# - Example of the Permedia structural model—prior to attribution of reservoir properties. The regional seismic surfaces used to compartmentalise the model are labelled on the right (top seabed surface is not shown).

# %% [markdown]
# # SFM and CO2 migration modelling
#
#
# <br/>
# <div align="center">
#     <img width=800 src="figures/gipps7.png" title="gipps7"</img>
#     <small>[source](https://www.researchgate.net/profile/John_Miranda/publication/259240166_Gippsland_Basin_stratigraphic_and_CO2_migration_modelling_workflows_for_building_regional_geological_carbon_storage_%28GCS%29_reservoir_models/links/00b4952a93537de3e6000000.pdf)</small>
# </div>
#
# ---
#
# - Gocad is a data-based, three-dimensional geometrical modelling scheme which uses a discrete mathematical approach to integrate information (Mallet 1992) and allows the interactive manipulation and visualisation of various types of geological models.
# - Gocad is used here to qualitatively distribute within the Permedia structural model both the simulated porosity data derived from Sedsim and the log-derived porosity data at well locations.
#
# The above figure shows:
#
# - Fence diagram showing the porosity distribution within the Gippsland Basin model following attribution within **Gocad**.
# - Well locations are depicted by derricks and well paths are shown as red lines.
# - The individual porosity data points along the well paths are not shown because they are below the resolution of the image.

# %% [markdown]
# # SFM and CO2 migration modelling
#
#
# <br/>
# <div align="center">
#     <img width=800 src="figures/gipps10.png" title="gipps10"</img>
#     <small>[source](https://www.researchgate.net/profile/John_Miranda/publication/259240166_Gippsland_Basin_stratigraphic_and_CO2_migration_modelling_workflows_for_building_regional_geological_carbon_storage_%28GCS%29_reservoir_models/links/00b4952a93537de3e6000000.pdf)</small>
# </div>
#
# ---
#
# - Contoured map showing the depth to the top of the Latrobe Group.
# - The site of the simulated injection well is shown with respect to the small structural high target (and nearby control wells).

# %% [markdown]
# # SFM and CO2 migration modelling
#
#
# <br/>
# <div align="center">
#     <img width=800 src="figures/gipps9.png" title="gipps9"</img>
#     <small>[source](https://www.researchgate.net/profile/John_Miranda/publication/259240166_Gippsland_Basin_stratigraphic_and_CO2_migration_modelling_workflows_for_building_regional_geological_carbon_storage_%28GCS%29_reservoir_models/links/00b4952a93537de3e6000000.pdf)</small>
# </div>
#
# ---
#
# Results of CO2 injection simulation in the nearshore/onshore Gippsland Basin from Permedia.
#
# - A. Cross-section showing CO2 saturation and the extent of the CO2 plume after 10 years of simulation. The plume has breached the intraformational seals, but not the regional top seal. Dark grey layers represent sealing lithologies within the Latrobe Group, while the light grey colour at the top represents the regional seal.
# - B. Cross-section showing CO2 saturation and the extent of the CO2 plume after 70 years of simulation. The plume has filled the target structure and shows minor migration towards the west. Residually trapped CO2 saturations are displayed as transparent blue colours within the plume. Dark grey layers represent sealing lithologies within the Latrobe Group, while the light grey colour at the top represents the regional seal.
# - C. Graphical summary of CO2 dissolution (red) after injection (blue) (70 years of simulation).
# - D. Aerial extent (top view) of the simulated plume after 70 years.

# %% [markdown]
# # Quantitative seismic interpretation: seismic attributes
# <br/>
# <div align="center">
#     <img width=1000 src="http://www.dgi.com/images/cvslideshow/fullsize/CoViz4D_Slideshow_003.jpg" title="Integration of multi-disciplinary data, including reservoir simulation, 4D seismic, seismic attribute extractions, structure model, and production data."</img>
#     <small>source: [DGI](http://www.dgi.com/coviz/cvmain.html)</small>
# </div>
# <br/>
#
# ---
#
# ### What are seismic attributes?
#
# - Any measurement **derived** from the seismic data
# - Seismic attributes typically provide information relating to the **amplitude**, **shape**, and/or **position** of the seismic waveform.
# - Seismic attributes reveal features, relationships, and patterns in the seismic data that otherwise might not be noticed.

# %% [markdown]
# ## General classes of attributes
#
# <br/>
# <div align="center">
#     <img width=1000 src="http://agilegeoscience.squarespace.com/storage/post-images/Amplitude.png" title="."</img>
#     <small>source: [Agile](http://agilegeoscience.squarespace.com/journal/tag/attributes?currentPage=3)</small>
# </div>
# <br/>
#
# ---
#
# - 1D attributes: operate on a single stacked seismic trace
# - 2D and 3D attributes: calculated using information from adjacent traces
#
#
# ## Physical information provided by seismic attributes:
#
# - **Envelope**: presence of gas, thin-bed tuning effects, lithology changes
# - **Phase**: lateral continuity of refloectors, bedding configurations
# - **Frequency**: bed thickness, presence of hydrocarbons, fracture zones
# - **Spectral decomposiiton**: bed thickness
# - **Coherence, Volumetric curvature**: faults, fractures, kateral stratigraphic discontinuities

# %% [markdown]
# # Quantitative seismic interpretation
# <br/>
# <div align="center">
#     <img width=1000 src="http://rocksolidimages.com/images/Quantitative-interpretation.png" title="Inputs and outputs for Quantitative Interpretation"</img>
#     <small>source: [rocksolid](http://rocksolidimages.com/seismic-services.html)</small>
# </div>
# <br/>
#
# ---
#
# **Quantitative seismic interpretation applies rock physics to predict reservoir parameters, such as lithologies and pore fluids, from seismically derived attributes**.

# %% [markdown]
# # Creating synthetic data from well log
#
#
# [notebook](https://vm-43-240-96-53.intersect.nectar.org.au:9999/notebooks/GEOS3102/WellAnalysis/SyntheticWell.ipynb)
#
# **Starting from a well log, we  create a synthetic dataset of elastic properties (Vp, Vs, density, etc.). **
# <br/>
#
# The idea is that the wells cannot possibly sample all the complexity and variations occurring across a reservoir. Using various techniques to synthesize new data and create an _abstraction_ of a considered reservoir we will investigate alternative and plausible scenarios such as:
#
# - change of pore fluids;
# - lithological variations.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import pandas as pd
from IPython.html.widgets import interact, interactive, fixed
from IPython.html import widgets
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %% [markdown]
# # Well log data
#
# The well log we will use is part of the test datasets available on the **Quantitative Seismic Interpretation** book website:
#
# <https://pangea.stanford.edu/researchgroups/srb/resources/books/quantitative-seismic-interpretation>

# %%
WELL = pd.read_csv('WellAnalysis/WellData/qsiwell2.csv')

# %% [markdown]
# # Calculating a litho-facies log
#
# We are now going to calculate a _Litho-Fluid Class_ log (LFC), where you will separate groups of data identified by similar lithological and/or pore fluid content. The values of the LFC log will be assigned following these rules:
#
# * LFC=0: undef
# * LFC=1: brine sand
# * LFC=2: oil sand
# * LFC=3: gas sand
# * LFC=4: shale

# %%
# Define depth window
WELL = WELL.ix[(WELL.DEPTH>=2100) & (WELL.DEPTH<=2400)]

# Cutoff value for differentiating between sand and shale
sand_cutoff = 0.20

# Sand litho-facies flags
ssb = ( ( WELL.VSH <= sand_cutoff) & (WELL.SW >= 0.9 ) ) # brine sand
sso = ( ( WELL.VSH <= sand_cutoff) & (WELL.SW < 0.9 ) )  # oil sand

# Shales flag
sh=(WELL.VSH > sand_cutoff)                     # shales

temp_lfc = np.zeros( np.shape( WELL.VSH ) )

#  LFC will be 1 when ssb (brine sand flag) is True
temp_lfc[ssb.values] = 1  
  # LFC will be 2 when sso (oil sand flag) is True
temp_lfc[sso.values] = 2    
# LFC will be 4 when sh (shale flag) is True
temp_lfc[sh.values] = 4     

# copy the temporary log temp_lfc into the DataFrame `WELL` with name `LFC`
WELL['LFC'] = temp_lfc

# %%
WELL.VP.hist(bins=50, color='black', by=WELL.LFC, figsize=(12,2), layout=(1,3), lw=0)
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x7fef2e2e7f10>,
# ...
#        <matplotlib.axes.AxesSubplot object at 0x7fef2365b710>], dtype=object)

# %% [markdown]
# # LFC plots

# %%
#  0=undef   1=bri  2=oil   3=gas 4=shale
ccc = ['#B3B3B3','blue','green','red','#996633',]
cmap_facies = colors.ListedColormap(ccc[0:len(ccc)], 'indexed')
ztop=2100; zbot=2400

# Set the depth window
ll=WELL.ix[(WELL.DEPTH>=ztop) & (WELL.DEPTH<=zbot)]

# Initialise LFC data
cluster=np.repeat(np.expand_dims(ll['LFC'].values,1),100,1)

# Define plot window
f, ax = plt.subplots(nrows=1, ncols=4, figsize=(8, 12))

# Define plot 0: shale volume, water saturation, porosity
ax[0].plot(ll.VSH, ll.DEPTH, '-g', label='Vsh')
ax[0].plot(ll.SW, ll.DEPTH, '-b', label='Sw')
ax[0].plot(ll.PHI, ll.DEPTH, '-k', label='phi')

# Define plot 1: acoustic impedance. (Ip)
ax[1].plot(ll.IP, ll.DEPTH, '-', color='0.5')

# Define plot 2: VpVs ratio
ax[2].plot(ll.VPVS, ll.DEPTH, '-', color='0.5')

# Define plot 3: set colormap
im=ax[3].imshow(cluster, interpolation='none', aspect='auto',cmap=cmap_facies,vmin=0,vmax=4)

# Define plot 3 color bar
cbar=plt.colorbar(im, ax=ax[3])
# cbar.set_label('0=undef,1=brine,2=oil,3=gas,4=shale')
# cbar.set_ticks(range(0,4+1)); cbar.set_ticklabels(range(0,4+1))
cbar.set_label((12*' ').join(['undef', 'brine', 'oil', 'gas', 'shale']))
cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')

# Define Depth (y-axis)
for i in ax[:-1]:
    i.set_ylim(ztop,zbot)
    i.invert_yaxis()
    i.grid()
    i.locator_params(axis='x', nbins=4)
    
# Define legend and x-axis ranges
ax[0].legend(fontsize='small', loc='lower right')
ax[0].set_xlabel("Vcl/phi/Sw"),    ax[0].set_xlim(-.1,1.1)
ax[1].set_xlabel("Ip [m/s*g/cc]"), ax[1].set_xlim(3000,9000)
ax[2].set_xlabel("Vp/Vs"),         ax[2].set_xlim(1.5,3)
ax[3].set_xlabel('LFC')
ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([]); ax[3].set_xticklabels([]);

# %%
plt.figure(figsize=(8,6))

plt.scatter(WELL.IP,WELL.VPVS,20,WELL.LFC,marker='o',edgecolors='none',alpha=0.7,cmap=cmap_facies,vmin=0,vmax=4)

plt.xlim(3000,9000); plt.ylim(1.5,3); plt.grid(); plt.xlabel('Ip'); plt.ylabel('Vp/Vs')

cbar=plt.colorbar()
# cbar.set_label('0=undef,1=brine,2=oil,3=gas,4=shale')
# cbar.set_ticks(range(0,4+1)); cbar.set_ticklabels(range(0,4+1));

cbar.set_label((15*' ').join(['undef', 'brine', 'oil', 'gas', 'shale']))
cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
cbar.set_alpha(1)
cbar.draw_all()

# %% [markdown]
# # Fluid replacement modelling
#
# ## Gassmann's equation
#
# Fluid replacement modeling (FRM in short), based on [Gassmann's equation](http://cseg.ca/assets/files/resources/abstracts/2013/316_GC2013_A_look_into_Gassmanns_Equation.pdf), is one of the key activities for any kind of quantitative work (see Wang, 2001 and Smith et al., 2003, for an exhaustive overview).
#
# <div align="center">
#     <img width=800 src="http://geophysics.geoscienceworld.org/content/69/2/398/F3.medium.gif" title="Illustration of both the Voigt high and Reuss low bounds for dry rock, fluid-saturated rock, and bounds of predicted fluid-saturation effect by the Gassmann's equation."</img>
#     <small>source: [Geophysics](http://geophysics.geoscienceworld.org)</small>
# </div>
# <br/>
#
#
# It is used to model the response of elastic logs (i.e., Vp, Vs and density) in different fluid conditions, thus allowing to study how much a rock would change in terms of velocity (or impedances) if it was filled with gas instead of brine for example; but what it also does is to bring all elastic logs to a *common fluid denominator* to focus only on lithological variations, disregarding fluid effects.

# %%
# Fluid replacement modeling function
def frm(vp1, vs1, rho1, rho_fl1, k_fl1, rho_fl2, k_fl2, km, phi):
    vp1=vp1/1000
    vs1=vs1/1000
    rho2 = rho1-phi*rho_fl1+phi*rho_fl2
    mu1 = rho1*vs1**2.
    k1 = rho1*vp1**2-(4./3.)*mu1
    kdry= (k1 * ((phi*k0)/k_fl1+1-phi)-k0) / ((phi*k0)/k_fl1+(k1/k0)-1-phi)
    k2 = kdry + (1- (kdry/k0))**2 / ( (phi/k_fl2) + ((1-phi)/k0) - (kdry/k0**2) )
    mu2 = mu1
    vp2 = np.sqrt(((k2+(4./3)*mu2))/rho2)
    vs2 = np.sqrt((mu2/rho2))
    return [vp2*1000, vs2*1000, rho2, k2]

# Voigt-Reuss-Hill averaging equation
def vrh(volumes,k,mu):
    f=np.array(volumes).T
    k=np.resize(np.array(k),np.shape(f))
    mu=np.resize(np.array(mu),np.shape(f))

    k_u = np.sum(f*k,axis=1)
    k_l = 1./np.sum(f/k,axis=1)
    mu_u = np.sum(f*mu,axis=1)
    mu_l = 1./np.sum(f/mu,axis=1)
    k0 = (k_u+k_l)/2.
    mu0 = (mu_u+mu_l)/2.
    return [k_u, k_l, mu_u, mu_l, k0, mu0]

rho_qz=2.65;  k_qz=37;  mu_qz=44    # mineral properties, quartz (i.e., sands)
rho_sh=2.81;  k_sh=15;  mu_sh=5     # mineral properties, clay (i.e., shales)
rho_b=1.09;   k_b=2.8               # fluid properties, brine
rho_o=0.78;   k_o=0.94              # fluid properties, oil
rho_g=0.25;   k_g=0.06              # fluid properties, gas

# %%
# mineral mixture bulk and shear moduli, k0 and mu0
shale=WELL.VSH.values
sand=1-shale-WELL.PHI.values
shaleN = shale/(shale+sand)  # normalized shale and sand volumes
sandN  = sand/(shale+sand)

# Voigt-Reuss-Hill averaging
[k_u, k_l, mu_u, mu_l, k0, mu0]=vrh([shaleN, sandN],[k_sh,k_qz],[mu_sh,mu_qz])

# fluid mixture bulk modulus, using the same vrh function but capturing the Reuss average (second output)
water=WELL.SW.values
hc=1-WELL.SW.values
[tmp, k_fl, tmp, tmp, tmp, tmp]=vrh([water, hc],[k_b,k_o],[0,0])

# fluid mixture density
rho_fl=water*rho_b + hc*rho_o

[vpb, vsb, rhob, kb] = frm(WELL.VP, WELL.VS, WELL.RHO, rho_fl, k_fl, rho_b, k_b, k0, WELL.PHI)
[vpo, vso, rhoo, ko] = frm(WELL.VP, WELL.VS, WELL.RHO, rho_fl, k_fl, rho_o, k_o, k0, WELL.PHI)
[vpg, vsg, rhog, kg] = frm(WELL.VP, WELL.VS, WELL.RHO, rho_fl, k_fl, rho_g, k_g, k0, WELL.PHI)

WELL['VP_FRMB']=WELL.VP
WELL['VS_FRMB']=WELL.VS
WELL['RHO_FRMB']=WELL.RHO
WELL['VP_FRMB'][ssb|sso]=vpb[ssb|sso]
WELL['VS_FRMB'][ssb|sso]=vsb[ssb|sso]
WELL['RHO_FRMB'][ssb|sso]=rhob[ssb|sso]
WELL['IP_FRMB']=WELL.VP_FRMB*WELL.RHO_FRMB
WELL['IS_FRMB']=WELL.VS_FRMB*WELL.RHO_FRMB
WELL['VPVS_FRMB']=WELL.VP_FRMB/WELL.VS_FRMB

WELL['VP_FRMO']=WELL.VP
WELL['VS_FRMO']=WELL.VS
WELL['RHO_FRMO']=WELL.RHO
WELL['VP_FRMO'][ssb|sso]=vpo[ssb|sso]
WELL['VS_FRMO'][ssb|sso]=vso[ssb|sso]
WELL['RHO_FRMO'][ssb|sso]=rhoo[ssb|sso]
WELL['IP_FRMO']=WELL.VP_FRMO*WELL.RHO_FRMO
WELL['IS_FRMO']=WELL.VS_FRMO*WELL.RHO_FRMO
WELL['VPVS_FRMO']=WELL.VP_FRMO/WELL.VS_FRMO

WELL['VP_FRMG']=WELL.VP
WELL['VS_FRMG']=WELL.VS
WELL['RHO_FRMG']=WELL.RHO
WELL['VP_FRMG'][ssb|sso]=vpg[ssb|sso]
WELL['VS_FRMG'][ssb|sso]=vsg[ssb|sso]
WELL['RHO_FRMG'][ssb|sso]=rhog[ssb|sso]
WELL['IP_FRMG']=WELL.VP_FRMG*WELL.RHO_FRMG
WELL['IS_FRMG']=WELL.VS_FRMG*WELL.RHO_FRMG
WELL['VPVS_FRMG']=WELL.VP_FRMG/WELL.VS_FRMG

# %%
temp_lfc_b=np.zeros(np.shape(WELL.VSH))
temp_lfc_b[ssb.values | sso.values]=1  # LFC is 1 when either ssb (brine sand flag) or sso (oil) is True
temp_lfc_b[sh.values]=4                # LFC 4=shale
WELL['LFC_B']= temp_lfc_b

temp_lfc_o=np.zeros(np.shape(WELL.VSH))
temp_lfc_o[ssb.values | sso.values]=2  # LFC is now 2 when there's sand (ssb or sso is True)
temp_lfc_o[sh.values]=4                # LFC 4=shale
WELL['LFC_O']= temp_lfc_o

temp_lfc_g=np.zeros(np.shape(WELL.VSH))
temp_lfc_g[ssb.values | sso.values]=3  # LFC 3=gas sand
temp_lfc_g[sh.values]=4                # LFC 4=shale
WELL['LFC_G']= temp_lfc_g

ztop=2150; zbot=2200
ll=WELL.ix[(WELL.DEPTH>=ztop) & (WELL.DEPTH<=zbot)]

cluster=np.repeat(np.expand_dims(ll['LFC'].values,1),100,1)

f, ax = plt.subplots(nrows=1, ncols=4, figsize=(8, 12))
ax[0].plot(ll.VSH, ll.DEPTH, '-g', label='Vsh')
ax[0].plot(ll.SW, ll.DEPTH, '-b', label='Sw')
ax[0].plot(ll.PHI, ll.DEPTH, '-k', label='phi')
ax[1].plot(ll.IP_FRMG, ll.DEPTH, '-r')
ax[1].plot(ll.IP_FRMB, ll.DEPTH, '-b')
ax[1].plot(ll.IP, ll.DEPTH, '-', color='0.5')
ax[2].plot(ll.VPVS_FRMG, ll.DEPTH, '-r')
ax[2].plot(ll.VPVS_FRMB, ll.DEPTH, '-b')
ax[2].plot(ll.VPVS, ll.DEPTH, '-', color='0.5')
im=ax[3].imshow(cluster, interpolation='none', aspect='auto',cmap=cmap_facies,vmin=0,vmax=4)
cbar=plt.colorbar(im, ax=ax[3])
# cbar.set_label('0=undef,1=brine,2=oil,3=gas,4=shale')
# cbar.set_ticks(range(0,4+1)); 
cbar.set_label((12*' ').join(['undef', 'brine', 'oil', 'gas', 'shale']))
cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
for i in ax[:-1]:
    i.set_ylim(ztop,zbot)
    i.invert_yaxis()
    i.grid()
    i.locator_params(axis='x', nbins=4)
ax[0].legend(fontsize='small', loc='lower right')
ax[0].set_xlabel("Vcl/phi/Sw"),    ax[0].set_xlim(-.1,1.1)
ax[1].set_xlabel("Ip [m/s*g/cc]"), ax[1].set_xlim(3000,9000)
ax[2].set_xlabel("Vp/Vs"),         ax[2].set_xlim(1.5,3)
ax[3].set_xlabel('LFC')
ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([]); ax[3].set_xticklabels([]);

# %%
f, ax = plt.subplots(nrows=1, ncols=4, sharey=True, sharex=True, figsize=(16, 4))
ax[0].scatter(WELL.IP,WELL.VPVS,20,WELL.LFC,marker='o',edgecolors='none',alpha=0.5,cmap=cmap_facies,vmin=0,vmax=4)
ax[1].scatter(WELL.IP_FRMB,WELL.VPVS_FRMB,20,WELL.LFC_B,marker='o',edgecolors='none',alpha=0.5,cmap=cmap_facies,vmin=0,vmax=4)
ax[2].scatter(WELL.IP_FRMO,WELL.VPVS_FRMO,20,WELL.LFC_O,marker='o',edgecolors='none',alpha=0.5,cmap=cmap_facies,vmin=0,vmax=4)
ax[3].scatter(WELL.IP_FRMG,WELL.VPVS_FRMG,20,WELL.LFC_G,marker='o',edgecolors='none',alpha=0.5,cmap=cmap_facies,vmin=0,vmax=4)
ax[0].set_xlim(3000,9000); ax[0].set_ylim(1.5,3);
ax[0].set_title('original data');
ax[1].set_title('FRM to brine');
ax[2].set_title('FRM to oil');
ax[3].set_title('FRM to gas');
for i in ax: i.grid()

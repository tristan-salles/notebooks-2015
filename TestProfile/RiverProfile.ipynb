# %% [markdown]
# <h1> River profiles evolution

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
location1=r'/Users/tristan/Desktop/river/riv10000.1.csv'
location2=r'/Users/tristan/Desktop/river/riv10000.5.csv'
location3=r'/Users/tristan/Desktop/river/riv10000.10.csv'
location4=r'/Users/tristan/Desktop/river/riv10000.15.csv'
location5=r'/Users/tristan/Desktop/river/riv10000.20.csv'
location6=r'/Users/tristan/Desktop/river/riv10000.25.csv'
location7=r'/Users/tristan/Desktop/river/riv10000.30.csv'
location8=r'/Users/tristan/Desktop/river/riv10000.35.csv'
location9=r'/Users/tristan/Desktop/river/riv10000.40.csv'
location10=r'/Users/tristan/Desktop/river/riv10000.45.csv'

# %%
fulldata1 = pd.read_csv(location1)
fulldata2 = pd.read_csv(location2)
fulldata3 = pd.read_csv(location3)
fulldata4 = pd.read_csv(location4)
fulldata5 = pd.read_csv(location5)
fulldata6 = pd.read_csv(location6)
fulldata7 = pd.read_csv(location7)
fulldata8 = pd.read_csv(location8)
fulldata9 = pd.read_csv(location9)
fulldata10 = pd.read_csv(location10)
top = fulldata1.head(1)
top
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-206-2fd6c2dec63f> in <module>()
# ----> 1 fulldata1 = pd.read_csv(location1)
#       2 fulldata2 = pd.read_csv(location2)
#       3 fulldata3 = pd.read_csv(location3)
#       4 fulldata4 = pd.read_csv(location4)
#       5 fulldata5 = pd.read_csv(location5)
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     463                     skip_blank_lines=skip_blank_lines)
#     464
# --> 465         return _read(filepath_or_buffer, kwds)
#     466
#     467     parser_f.__name__ = name
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     239
#     240     # Create the parser.
# --> 241     parser = TextFileReader(filepath_or_buffer, **kwds)
#     242
#     243     if (nrows is not None) and (chunksize is not None):
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     555             self.options['has_index_names'] = kwds['has_index_names']
#     556
# --> 557         self._make_engine(self.engine)
#     558
#     559     def _get_options_with_defaults(self, engine):
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     692     def _make_engine(self, engine='c'):
#     693         if engine == 'c':
# --> 694             self._engine = CParserWrapper(self.f, **self.options)
#     695         else:
#     696             if engine == 'python':
#
# //anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1059         kwds['allow_leading_cols'] = self.index_col is not False
#    1060
# -> 1061         self._reader = _parser.TextReader(src, **kwds)
#    1062
#    1063         # XXX
#
# //anaconda/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3150)()
#
# //anaconda/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5772)()
#
# IOError: File /Users/tristan/Desktop/river/riv10000.1.csv does not exist

# %%
data1 = fulldata1[["distance to outlet","Result"]]
data2 = fulldata2[["distance to outlet","Result"]]
data3 = fulldata3[["distance to outlet","Result"]]
data4 = fulldata4[["distance to outlet","Result"]]
data5 = fulldata5[["distance to outlet","Result"]]
data6 = fulldata6[["distance to outlet","Result"]]
data7 = fulldata7[["distance to outlet","Result"]]
data8 = fulldata8[["distance to outlet","Result"]]
data9 = fulldata9[["distance to outlet","Result"]]
data10 = fulldata10[["distance to outlet","Result"]]
top = data1.head(1)
top
# Out:
#    distance to outlet  Result
# 0                  50  488.31

# %%
df1 = data1.sort(['distance to outlet'], ascending=True)
df2 = data2.sort(['distance to outlet'], ascending=True)
df3 = data3.sort(['distance to outlet'], ascending=True)
df4 = data4.sort(['distance to outlet'], ascending=True)
df5 = data5.sort(['distance to outlet'], ascending=True)
df6 = data6.sort(['distance to outlet'], ascending=True)
df7 = data7.sort(['distance to outlet'], ascending=True)
df8 = data8.sort(['distance to outlet'], ascending=True)
df9 = data9.sort(['distance to outlet'], ascending=True)
df10 = data10.sort(['distance to outlet'], ascending=True)
top = df1.head(1)
top
# Out:
#    distance to outlet  Result
# 1                   0  487.27

# %%
x1 = np.array(df1[df1.columns[0::2]])
xmin = x1.min(axis=0)
xmax = x1.max(axis=0)
y1 = np.array(df1[df1.columns[1::2]])
x2 = np.array(df2[df2.columns[0::2]])
txmin = x2.min(axis=0)
txmax = x2.max(axis=0)
if txmin < xmin:
    xmin=txmin
if xmax < txmax:
    xmax=tmax
y2 = np.array(df2[df2.columns[1::2]])
x3 = np.array(df3[df3.columns[0::2]])
txmin = x3.min(axis=0)
txmax = x3.max(axis=0)
if txmin < xmin:
    xmin=txmin
if xmax < txmax:
    xmax=tmax
y3 = np.array(df3[df3.columns[1::2]])
x4 = np.array(df4[df4.columns[0::2]])
txmin = x4.min(axis=0)
txmax = x4.max(axis=0)
if txmin < xmin:
    xmin=txmin
if xmax < txmax:
    xmax=tmax
y4 = np.array(df4[df4.columns[1::2]])
x5 = np.array(df5[df5.columns[0::2]])
txmin = x5.min(axis=0)
txmax = x5.max(axis=0)
if txmin < xmin:
    xmin=txmin
if xmax < txmax:
    xmax=tmax
y5 = np.array(df5[df5.columns[1::2]])
x6 = np.array(df6[df6.columns[0::2]])
txmin = x6.min(axis=0)
txmax = x6.max(axis=0)
if txmin < xmin:
    xmin=txmin
if xmax < txmax:
    xmax=tmax
y6 = np.array(df6[df6.columns[1::2]])
x7 = np.array(df7[df7.columns[0::2]])
txmin = x7.min(axis=0)
txmax = x7.max(axis=0)
if txmin < xmin:
    xmin=txmin
if xmax < txmax:
    xmax=tmax
y7 = np.array(df7[df7.columns[1::2]])
x8 = np.array(df8[df8.columns[0::2]])
txmin = x8.min(axis=0)
txmax = x8.max(axis=0)
if txmin < xmin:
    xmin=txmin
if xmax < txmax:
    xmax=tmax
y8 = np.array(df8[df8.columns[1::2]])
x9 = np.array(df9[df9.columns[0::2]])
txmin = x9.min(axis=0)
txmax = x9.max(axis=0)
if txmin < xmin:
    xmin=txmin
if xmax < txmax:
    xmax=tmax
y9 = np.array(df9[df9.columns[1::2]])
x10 = np.array(df10[df10.columns[0::2]])
txmin = x10.min(axis=0)
txmax = x10.max(axis=0)
if txmin < xmin:
    xmin=txmin
if xmax < txmax:
    xmax=tmax
y10 = np.array(df10[df10.columns[1::2]])
print xmin,xmax
# Out:
# [ 0.] [ 0.]

# %%
# rescale
y1 = y1-y1[0]
ymin = y1.min(axis=0)
ymax = y1.max(axis=0)
y2 = y2-y2[0]
tmax = y2.max(axis=0)
if ymax < tmax:
    ymax=tmax
y3 = y3-y3[0]
tmax = y3.max(axis=0)
if ymax < tmax:
    ymax=tmax
y4 = y4-y4[0]
tmax = y4.max(axis=0)
if ymax < tmax:
    ymax=tmax
y5 = y5-y5[0]
tmax = y5.max(axis=0)
if ymax < tmax:
    ymax=tmax
y6 = y6-y6[0]
tmax = y6.max(axis=0)
if ymax < tmax:
    ymax=tmax
y7 = y7-y7[0]
tmax = y7.max(axis=0)
if ymax < tmax:
    ymax=tmax
y8 = y8-y8[0]
tmax = y8.max(axis=0)
if ymax < tmax:
    ymax=tmax
y9 = y9-y9[0]
tmax = y9.max(axis=0)
if ymax < tmax:
    ymax=tmax
y10 = y10-y10[0]
tmax = y10.max(axis=0)
if ymax < tmax:
    ymax=tmax
print ymin,ymax
# Out:
# [ 0.] [ 391.25]

# %%
figure = plt.figure()
figure.set_dpi(500)
figure.set_size_inches(14, 7)
plt.plot(x1, y1, label='250 kyr')
plt.plot(x3, y3, label='300 kyr')
plt.plot(x4, y4, label='325 kyr')
plt.plot(x5, y5, label='350 kyr')
plt.plot(x6, y6, label='375 kyr')
plt.plot(x7, y7, label='400 kyr')
plt.plot(x8, y8, label='425 kyr')
plt.plot(x9, y9, label='450 kyr')
plt.plot(x10, y10, label='475 kyr')
plt.plot(x2, y2, label='500 kyr')
legend = plt.legend(loc='lower right', shadow=False,prop={'size':10})
legend.draw_frame(False)
plt.xlabel('distance to outlet')
plt.ylabel('elevation')
axes = plt.gca()
#axes.set_xlim([xmin,xmax])
axes.set_ylim([ymin,ymax])
figure.savefig('profile_500.png')

# %% [markdown]
# <h1> River profiles evolution

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
location1=r'/Users/tristan/Desktop/climate/profile2.csv'

# %%
fulldata1 = pd.read_csv(location1)

top = fulldata1.head(3)
top
# Out:
#    Flow discharge  Strahler stream order  Subcatchment Id  \
# 0       351560000                      5             1375
# 1       352580000                      5             1376
# 2       342540000                      5             1375
#
#    vtkOriginalPointIds  Points:0  Points:1  Points:2
# 0                    0     42088    400.00    9.5843
# 1                    1     41619    400.00    9.5834
# 2                    2     42040    802.24    9.5856

# %%
data1 = fulldata1[["Points:1","Points:2"]]

top = data1.head(1)
top
# Out:
#    Points:1  Points:2
# 0       400    9.5843

# %%
df1 = data1.sort(["Points:1"], ascending=True)
top = df1.head(1)
top
# Out:
#    Points:1  Points:2
# 0       400    9.5843

# %%
x1 = np.array(df1[df1.columns[0::2]])
y1 = np.array(df1[df1.columns[1::2]])

# %%
ymin = 0
ymax = 400
xmin = 0
xmax = 20000
figure = plt.figure()
figure.set_dpi(500)
figure.set_size_inches(10, 3)
plt.plot(x1, y1, label='2.5 Myr')

legend = plt.legend(loc='lower right', shadow=False,prop={'size':10})
legend.draw_frame(False)
plt.xlabel('distance to outlet')
plt.ylabel('elevation')
axes = plt.gca()
#axes.set_xlim([xmin,xmax])
axes.set_ylim([ymin,ymax])
figure.savefig('profile.png')

# %%
location1=r'/Users/tristan/Desktop/transport/PROF1/profevol2.0.csv'
location2=r'/Users/tristan/Desktop/transport/PROF1/profevol2.1.csv'
location3=r'/Users/tristan/Desktop/transport/PROF1/profevol2.2.csv'
location4=r'/Users/tristan/Desktop/transport/PROF1/profevol2.3.csv'
location5=r'/Users/tristan/Desktop/transport/PROF1/profevol2.4.csv'
location6=r'/Users/tristan/Desktop/transport/PROF1/profevol2.5.csv'
location7=r'/Users/tristan/Desktop/transport/PROF1/profevol2.6.csv'
fulldata1 = pd.read_csv(location1)
fulldata2 = pd.read_csv(location2)
fulldata3 = pd.read_csv(location3)
fulldata4 = pd.read_csv(location4)
fulldata5 = pd.read_csv(location5)
fulldata6 = pd.read_csv(location6)
fulldata7 = pd.read_csv(location7)
data1 = fulldata1[["Points:1","Points:2"]]
data2 = fulldata2[["Points:1","Points:2"]]
data3 = fulldata3[["Points:1","Points:2"]]
data4 = fulldata4[["Points:1","Points:2"]]
data5 = fulldata5[["Points:1","Points:2"]]
data6 = fulldata6[["Points:1","Points:2"]]
data7 = fulldata7[["Points:1","Points:2"]]
df1 = data1.sort(["Points:1"], ascending=True)
df2 = data2.sort(["Points:1"], ascending=True)
df3 = data3.sort(["Points:1"], ascending=True)
df4 = data4.sort(["Points:1"], ascending=True)
df5 = data5.sort(["Points:1"], ascending=True)
df6 = data6.sort(["Points:1"], ascending=True)
df7 = data7.sort(["Points:1"], ascending=True)
x1 = np.array(df1[df1.columns[0::2]])
y1 = np.array(df1[df1.columns[1::2]])
x2 = np.array(df2[df2.columns[0::2]])
y2 = np.array(df2[df2.columns[1::2]])
x3 = np.array(df3[df3.columns[0::2]])
y3 = np.array(df3[df3.columns[1::2]])
x4 = np.array(df4[df4.columns[0::2]])
y4 = np.array(df4[df4.columns[1::2]])
x5 = np.array(df5[df5.columns[0::2]])
y5 = np.array(df5[df5.columns[1::2]])
x6 = np.array(df6[df6.columns[0::2]])
y6 = np.array(df6[df6.columns[1::2]])
x7 = np.array(df7[df7.columns[0::2]])
y7 = np.array(df7[df7.columns[1::2]])
ymin = 0
ymax = 500
xmin = 0
xmax = 20000
figure = plt.figure()
figure.set_dpi(500)
figure.set_size_inches(10, 5)
plt.plot(x1, y1, label='5 Myr')
plt.plot(x6, y6, label='5.05 Myr')
plt.plot(x2, y2, label='5.1 Myr')
plt.plot(x3, y3, label='5.25 Myr')
plt.plot(x4, y4, label='5.4 Myr')
plt.plot(x5, y5, label='5.55 Myr')
plt.plot(x7, y7, label='10 Myr')

legend = plt.legend(loc='lower right', shadow=False,prop={'size':10})
legend.draw_frame(False)
plt.xlabel('distance to outlet')
plt.ylabel('elevation')
axes = plt.gca()
#axes.set_xlim([xmin,xmax])
axes.set_ylim([ymin,ymax])
figure.savefig('profile_500.png')

# %% [markdown]
# #####
